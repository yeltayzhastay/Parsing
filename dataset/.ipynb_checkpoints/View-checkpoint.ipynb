# %%
import pandas as pd

# %%
df = pd.read_csv('vk_dataset.csv', sep=';')
df
# Out:
#              group_url    user_id first_name   last_name  sex     bdate  \
# 0     samsung.galaxy_a       3744  Alexander      Ageyev    2      10.5
# 1     samsung.galaxy_a      54512  Alexandra  Timoshenko    1      17.2
# 2     samsung.galaxy_a      63171     Oksana    Komarova    1       4.4
# 3     samsung.galaxy_a     120470  Alexandra   Saltykova    1  4.7.1990
# 4     samsung.galaxy_a     148878       Anna    Sergeeva    1      26.8
# ...                ...        ...        ...         ...  ...       ...
# 4995           ru_oppo  119043212     Dmitry    Dmitriev    2       NaN
# 4996           ru_oppo  119328330       Rita     Kromova    1       NaN
# 4997           ru_oppo  119494669    DELETED         NaN    2       NaN
# 4998           ru_oppo  119728965       Nina     Kichina    1  1.3.1991
# 4999           ru_oppo  120101837   Viktoria   Yakovleva    1       9.9
#
#      interests books   tv quotes  ... political smoking     religion  \
# ...

# %%
df.columns
# Out:
# Index(['group_url', 'user_id', 'first_name', 'last_name', 'sex', 'bdate',
#        'interests', 'books', 'tv', 'quotes', 'about', 'games', 'movies',
#        'music', 'status', 'followers_count', 'relation', 'city', 'country',
#        'alcohol', 'life_main', 'people_main', 'political', 'smoking',
#        'religion', 'langs', 'inspired_by', 'text', 'comments', 'likes',
#        'reposts', 'views'],
#       dtype='object')

# %%
df.groupby('group_url').count()[['user_id']]
# Out:
#                        user_id
# group_url
# huaweip20                 1000
# kupit_iphone_v_moskve     1000
# ru_oppo                   1000
# rumicomrussia             1000
# samsung.galaxy_a          1000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   group_url        5000 non-null   object
#  1   user_id          5000 non-null   int64
#  2   first_name       5000 non-null   object
#  3   last_name        4798 non-null   object
#  4   sex              5000 non-null   int64
#  5   bdate            3414 non-null   object
#  6   interests        326 non-null    object
#  7   books            258 non-null    object
#  8   tv               207 non-null    object
#  9   quotes           308 non-null    object
#  10  about            269 non-null    object
#  11  games            241 non-null    object
#  12  movies           291 non-null    object
#  13  music            304 non-null    object
#  14  status           1716 non-null   object
#  15  followers_count  2952 non-null   float64
# ...
