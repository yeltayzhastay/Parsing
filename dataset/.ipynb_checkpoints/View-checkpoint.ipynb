# %%
import pandas as pd

# %%
df = pd.read_csv('vk_dataset_2ipru.csv', sep=';')
df
# Out:
# c:\users\yelzha\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                    group_url   user_id first_name  last_name  sex       bdate  \
# 0      kupit_iphone_v_moskve      1704      Lizik   Sergeeva    1         NaN
# 1      kupit_iphone_v_moskve      3402       Ivan   Shmelyov    2         NaN
# 2      kupit_iphone_v_moskve      8206     Viktor    Smirnov    2         NaN
# 3      kupit_iphone_v_moskve      8571    Evgenia    Brenner    2         NaN
# 4      kupit_iphone_v_moskve     12435     Leodin    Semenov    2         NaN
# ...                      ...       ...        ...        ...  ...         ...
# 19995          rumicomrussia  25699214      Roman  Romanenko    2       10.11
# 19996          rumicomrussia  25701918      Zheka   Zavarzin    2   16.9.1994
# 19997          rumicomrussia  25706565      Irina  Tikhonova    1       11.10
# 19998          rumicomrussia  25707210   Nadezhda     Berndt    1  27.12.1990
# 19999          rumicomrussia  25707307  Alexander     Kaplin    2       12.11
#
#       interests books   tv quotes  ... political smoking religion    langs  \
# 0           NaN   NaN  NaN    NaN  ...       NaN     NaN      NaN      NaN
# 1           NaN   NaN  NaN    NaN  ...       NaN     NaN      NaN      NaN
# 2           NaN   NaN  NaN    NaN  ...       NaN     NaN      NaN      NaN
# 3           NaN   NaN  NaN    NaN  ...       NaN     NaN      NaN      NaN
# 4           NaN   NaN  NaN    NaN  ...       NaN     NaN      NaN      NaN
# ...         ...   ...  ...    ...  ...       ...     ...      ...      ...
# 19995       NaN   NaN  NaN    NaN  ...       NaN     NaN      NaN      NaN
# 19996       NaN   NaN  NaN    NaN  ...       NaN     0.0      NaN  Русский
# 19997       NaN   NaN  NaN    NaN  ...       NaN     NaN      NaN  Русский
# 19998       NaN   NaN  NaN    NaN  ...       NaN     NaN      NaN      NaN
# 19999       NaN   NaN  NaN    NaN  ...       NaN     NaN      NaN      NaN
#
#       inspired_by  text  comments likes reposts  views
# 0             NaN   NaN       NaN   NaN     NaN    NaN
# 1             NaN   NaN       NaN   NaN     NaN    NaN
# 2             NaN   NaN       NaN   NaN     NaN    NaN
# 3             NaN   NaN       NaN   NaN     NaN    NaN
# 4             NaN   NaN       NaN   NaN     NaN    NaN
# ...           ...   ...       ...   ...     ...    ...
# 19995         NaN   NaN       NaN   NaN     NaN    NaN
# 19996         NaN   NaN       NaN   NaN     NaN    NaN
# 19997         NaN   NaN       NaN   NaN     NaN    NaN
# 19998         NaN   NaN       NaN   NaN     NaN    NaN
# 19999         NaN   NaN       NaN   NaN     NaN    NaN
#
# [20000 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['group_url', 'user_id', 'first_name', 'last_name', 'sex', 'bdate',
#        'interests', 'books', 'tv', 'quotes', 'about', 'games', 'movies',
#        'music', 'status', 'followers_count', 'relation', 'city', 'country',
#        'alcohol', 'life_main', 'people_main', 'political', 'smoking',
#        'religion', 'langs', 'inspired_by', 'text', 'comments', 'likes',
#        'reposts', 'views'],
#       dtype='object')

# %%
df.groupby('group_url').count()[['user_id']]
# Out:
#                        user_id
# group_url
# kupit_iphone_v_moskve    10000
# rumicomrussia            10000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   group_url        20000 non-null  object
#  1   user_id          20000 non-null  int64
#  2   first_name       20000 non-null  object
#  3   last_name        18537 non-null  object
#  4   sex              20000 non-null  int64
#  5   bdate            13832 non-null  object
#  6   interests        1278 non-null   object
#  7   books            1115 non-null   object
#  8   tv               885 non-null    object
#  9   quotes           1210 non-null   object
#  10  about            1086 non-null   object
#  11  games            1001 non-null   object
#  12  movies           1228 non-null   object
#  13  music            1337 non-null   object
#  14  status           7786 non-null   object
#  15  followers_count  12951 non-null  float64
#  16  relation         4566 non-null   float64
#  17  city             14941 non-null  object
#  18  country          16532 non-null  object
#  19  alcohol          3007 non-null   float64
#  20  life_main        2972 non-null   float64
#  21  people_main      2986 non-null   float64
#  22  political        1593 non-null   float64
#  23  smoking          3013 non-null   float64
#  24  religion         1228 non-null   object
#  25  langs            3429 non-null   object
#  26  inspired_by      718 non-null    object
#  27  text             2034 non-null   object
#  28  comments         2034 non-null   float64
#  29  likes            2034 non-null   float64
#  30  reposts          2034 non-null   float64
#  31  views            2034 non-null   float64
# dtypes: float64(11), int64(2), object(19)
# memory usage: 4.9+ MB

# %%
df.loc[df['text'].dropna().index, :]
# Out:
#                   group_url    user_id  first_name     last_name  sex  \
# 14    kupit_iphone_v_moskve      95276    Abastina      Abramova    1
# 20    kupit_iphone_v_moskve     110965  Konstantin        Karpov    2
# 23    kupit_iphone_v_moskve     141937      Dmitry    Kozhemyako    2
# 24    kupit_iphone_v_moskve     143011    Vladimir      Everlast    2
# 33    kupit_iphone_v_moskve     284394        Yury        Butvin    2
# ...                     ...        ...         ...           ...  ...
# 4988  kupit_iphone_v_moskve  146281032    Svetlana      Lipatova    1
# 4989  kupit_iphone_v_moskve  146283970    Viktoria        Svisch    1
# 4993  kupit_iphone_v_moskve  146328982       Maria    Korshunova    1
# 4994  kupit_iphone_v_moskve  146352454       Irina  Davidovskaya    1
# 4995  kupit_iphone_v_moskve  146371848        Anna       Pavlova    1
#
#           bdate                                          interests books  \
# 14          NaN                                                NaN   NaN
# 20          NaN                                                NaN   NaN
# 23          NaN  карповая рыбалка, подводная охота, дайвинг, се...  что?
# 24     8.8.1988                                                NaN   NaN
# 33          6.6                                                NaN   NaN
# ...         ...                                                ...   ...
# 4988        NaN                                                NaN   NaN
# 4989        NaN  танцы, спорт, отдых на природе, общение с друз...   NaN
# 4993  15.6.1991                                                NaN   NaN
# 4994      15.10                                                NaN   NaN
# 4995  28.3.1991                                                NaN   NaN
#
#         tv                                             quotes  ... political  \
# 14     NaN                                                NaN  ...       NaN
# 20     NaN                                                NaN  ...       NaN
# 23    что?  Чтобы тебя любили - приходится быть со всеми х...  ...       NaN
# 24     NaN                                                NaN  ...       NaN
# 33     NaN                                                NaN  ...       NaN
# ...    ...                                                ...  ...       ...
# 4988   NaN                                                NaN  ...       NaN
# 4989   NaN                                                NaN  ...       NaN
# 4993   NaN                                                NaN  ...       NaN
# 4994   NaN                                                NaN  ...       NaN
# 4995   NaN                                                NaN  ...       NaN
#
#      smoking     religion    langs inspired_by  \
# 14       NaN          NaN      NaN         NaN
# 20       NaN          NaN      NaN         NaN
# 23       NaN          NaN  Русский         NaN
# 24       NaN  Православие  Русский         NaN
# 33       0.0          NaN      NaN         NaN
# ...      ...          ...      ...         ...
# 4988     NaN          NaN      NaN         NaN
# 4989     NaN          NaN      NaN         NaN
# 4993     NaN          NaN      NaN         NaN
# 4994     NaN          NaN      NaN         NaN
# 4995     NaN          NaN      NaN         NaN
#
#                                                    text  comments       likes  \
# 14                                                       2.380000  123.660000
# 20                 Красная зона: эксклюзив из реаним...  0.000000    0.580000
# 23                                                       0.000000  112.430769
# 24    С Днём Рождения!!! 🎉🎉🎉🎈🎈🎈🎁🎁🎁🍹🍹🍹  С Днём Рожден...  0.116279    1.093023
# 33                                                       0.000000  206.566667
# ...                                                 ...       ...         ...
# 4988                                                     0.000000    0.110000
# 4989  Узнай своих поклонников! vk.com/app4236781_296...  0.000000    0.012500
# 4993  Мои чувства уязвимы.. А я нет! - я больше!!\r\...  0.000000    3.610000
# 4994    Друзья, активно голосуем за Явера Касумова! ...  0.000000    3.870000
# 4995  Ревность я твою не понимаю, \r\nИ в пoследний ...  0.000000    3.570000
#
#        reposts         views
# 14    0.340000   3926.520000
# 20    0.090000     51.190000
# 23    8.892308  23392.846154
# 24    0.034884     31.825581
# 33    0.666667   2224.566667
# ...        ...           ...
# 4988  0.020000     10.070000
# 4989  0.000000      0.000000
# 4993  0.000000     57.470000
# 4994  0.000000     91.750000
# 4995  0.000000    119.120000
#
# [2034 rows x 32 columns]

# %%
df.loc[df['text'].dropna().index, :].groupby('group_url').count()[['user_id']]
# Out:
#                        user_id
# group_url
# kupit_iphone_v_moskve     2034

# %%
df['text'].dropna()
# Out:
# 14
# 20                   Красная зона: эксклюзив из реаним...
# 23
# 24      С Днём Рождения!!! 🎉🎉🎉🎈🎈🎈🎁🎁🎁🍹🍹🍹  С Днём Рожден...
# 33
#                               ...
# 4988
# 4989    Узнай своих поклонников! vk.com/app4236781_296...
# 4993    Мои чувства уязвимы.. А я нет! - я больше!!\r\...
# 4994      Друзья, активно голосуем за Явера Касумова! ...
# 4995    Ревность я твою не понимаю, \r\nИ в пoследний ...
# Name: text, Length: 2034, dtype: object
